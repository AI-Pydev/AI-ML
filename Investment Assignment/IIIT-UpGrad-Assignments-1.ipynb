# %% [markdown]
# # Business and Data Understanding
# #### Spark Funds has two minor constraints for investments:
#  -  It wants to invest between 5 to 15 million USD per round of investment
#  -  It wants to invest only in English-speaking countries because of the ease of communication with the companies it would invest in
#  -  For your analysis, consider a country to be English speaking only if English is one of the official languages in that country
#  -  You may use this list: Click [here](https://en.wikipedia.org/wiki/List_of_territorial_entities_where_English_is_an_official_language) for a list of countries where English is an official language.

# %%
# loading libraries 
import numpy as np
import pandas as pd
from urllib.parse import unquote

# %%
# reading the data from the provided data
companies = pd.read_csv("data/companies.txt", sep="\t", encoding = "ISO-8859-1")
mapping_df = pd.read_csv('data/mapping.csv', encoding = "ISO-8859-1")
rounds2 = pd.read_csv('data/rounds2.csv', encoding = "ISO-8859-1")
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /Organization/-Fame                   #fame
# 1               /Organization/-Qounter                :Qounter
# 2  /Organization/-The-One-Of-Them-Inc-  (THE) ONE of THEM,Inc.
# 3                /Organization/0-6-Com                 0-6.com
# 4       /Organization/004-Technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# 3                                        Curated Web  operating          CHN
# 4                                           Software  operating          USA
#
#   state_code                 region           city  founded_at
# 0         16                 Mumbai         Mumbai         NaN
# 1         DE             DE - Other  Delaware City  04-09-2014
# 2        NaN                    NaN            NaN         NaN
# 3         22                Beijing        Beijing  01-01-2007
# 4         IL  Springfield, Illinois      Champaign  01-01-2010

# %%
companies.tail()
# Out:
#                                                permalink  \
# 66363  /Organization/Zznode-Science-And-Technology-Co...
# 66364                          /Organization/Zzzzapp-Com
# 66365                               /Organization/ÃEron
# 66366                             /Organization/ÃAsys-2
# 66367  /Organization/Ä°Novatiff-Reklam-Ve-Tanä±Tä±M-H...
#
#                                                 name            homepage_url  \
# 66363                  ZZNode Science and Technology   http://www.zznode.com
# 66364                          Zzzzapp Wireless ltd.  http://www.zzzzapp.com
# 66365                                         ÃERON    http://www.aeron.hu/
# 66366                                         Ãasys    http://www.oasys.io/
# 66367  Ä°novatiff Reklam ve TanÄ±tÄ±m Hizmetleri Tic    http://inovatiff.com
#
#                                            category_list     status  \
# 66363                                Enterprise Software  operating
# 66364        Advertising|Mobile|Web Development|Wireless  operating
# 66365                                                NaN  operating
# 66366  Consumer Electronics|Internet of Things|Teleco...  operating
# 66367                 Consumer Goods|E-Commerce|Internet  operating
#
#       country_code state_code       region           city  founded_at
# 66363          CHN         22      Beijing        Beijing         NaN
# 66364          HRV         15        Split          Split  13-05-2012
# 66365          NaN        NaN          NaN            NaN  01-01-2011
# 66366          USA         CA  SF Bay Area  San Francisco  01-01-2014
# 66367          NaN        NaN          NaN            NaN         NaN

# %%
companies.shape
# Out:
# (66368, 10)

# %%
companies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66368 entries, 0 to 66367
# Data columns (total 10 columns):
# permalink        66368 non-null object
# name             66367 non-null object
# homepage_url     61310 non-null object
# category_list    63220 non-null object
# status           66368 non-null object
# country_code     59410 non-null object
# state_code       57821 non-null object
# region           58338 non-null object
# city             58340 non-null object
# founded_at       51147 non-null object
# dtypes: object(10)
# memory usage: 5.1+ MB

# %%
companies["permalink"] = companies['permalink'].str.lower().apply(lambda x: unquote(x))
companies.describe()
# Out:
#                                  permalink   name                homepage_url  \
# count                                66368  66367                       61310
# unique                               66368  66102                       61191
# top     /organization/rit-technologies-ltd  Roost  http://www.askforoffer.com
# freq                                     1      4                           5
#
#        category_list     status country_code state_code       region  \
# count          63220      66368        59410      57821        58338
# unique         27296          4          137        311         1092
# top         Software  operating          USA         CA  SF Bay Area
# freq            3995      53034        37601      12900         8804
#
#                  city  founded_at
# count           58340       51147
# unique           5111        3978
# top     San Francisco  01-01-2012
# freq             3526        2730

# %%
rounds2.shape
# Out:
# (114949, 6)

# %%
rounds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114949 entries, 0 to 114948
# Data columns (total 6 columns):
# company_permalink          114949 non-null object
# funding_round_permalink    114949 non-null object
# funding_round_type         114949 non-null object
# funding_round_code         31140 non-null object
# funded_at                  114949 non-null object
# raised_amount_usd          94959 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 5.3+ MB

# %%
rounds2.describe()
# Out:
#        raised_amount_usd
# count       9.495900e+04
# mean        1.042687e+07
# std         1.148212e+08
# min         0.000000e+00
# 25%         3.225000e+05
# 50%         1.680511e+06
# 75%         7.000000e+06
# max         2.127194e+10

# %%
companies.isnull().sum()
# Out:
# permalink            0
# name                 1
# homepage_url      5058
# category_list     3148
# status               0
# country_code      6958
# state_code        8547
# region            8030
# city              8028
# founded_at       15221
# dtype: int64

# %%
# rows which has missing vlaues
# companies.isnull().any()
# companies[companies.isnull().any(axis=1)]
# companies["name"].isnull().any()
companies.isnull().all()
# companies[companies.isnull().sum(axis=1) >5]
# Out:
# permalink        False
# name             False
# homepage_url     False
# category_list    False
# status           False
# country_code     False
# state_code       False
# region           False
# city             False
# founded_at       False
# dtype: bool

# %%
companies.isnull().any(axis=1).sum()
# Out:
# 23368

# %%
companies.isnull().sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        5
# 3        0
# 4        0
#         ..
# 66363    1
# 66364    0
# 66365    5
# 66366    0
# 66367    5
# Length: 66368, dtype: int64

# %%
# summing up the missing values (column-wise)d
round(100*(companies.isnull().sum()/len(companies.index)), 2)
# Out:
# permalink         0.00
# name              0.00
# homepage_url      7.62
# category_list     4.74
# status            0.00
# country_code     10.48
# state_code       12.88
# region           12.10
# city             12.10
# founded_at       22.93
# dtype: float64

# %%
companies = companies.loc[companies['status']!='closed']
companies.head()
# Out:
#                              permalink                    name  \
# 0                  /Organization/-Fame                   #fame
# 1               /Organization/-Qounter                :Qounter
# 2  /Organization/-The-One-Of-Them-Inc-  (THE) ONE of THEM,Inc.
# 3                /Organization/0-6-Com                 0-6.com
# 4       /Organization/004-Technologies        004 Technologies
#
#                         homepage_url  \
# 0                 http://livfame.com
# 1             http://www.qounter.com
# 2                http://oneofthem.jp
# 3                 http://www.0-6.com
# 4  http://004gmbh.de/en/004-interact
#
#                                        category_list     status country_code  \
# 0                                              Media  operating          IND
# 1  Application Platforms|Real Time|Social Network...  operating          USA
# 2                                  Apps|Games|Mobile  operating          NaN
# 3                                        Curated Web  operating          CHN
# 4                                           Software  operating          USA
#
#   state_code                 region           city  founded_at
# 0         16                 Mumbai         Mumbai         NaN
# 1         DE             DE - Other  Delaware City  04-09-2014
# 2        NaN                    NaN            NaN         NaN
# 3         22                Beijing        Beijing  01-01-2007
# 4         IL  Springfield, Illinois      Champaign  01-01-2010

# %%
companies[companies.isnull().sum(axis=1) > 5]
# Out:
#                                 permalink                  name  \
# 84              /Organization/1800Diapers           1800Diapers
# 122              /Organization/2-Ladoshki            2 Ladoshki
# 150                 /Organization/24-Quan               24 Quan
# 171                  /Organization/29West                29West
# 203       /Organization/2Web-Technologies     2Web Technologies
# ...                                   ...                   ...
# 66029             /Organization/Zingbox-2               ZingBox
# 66081  /Organization/Zippy-Com-Au-Pty-Ltd  Zippy.com.au Pty LTD
# 66120           /Organization/Zlote-Mysli           Zlote Mysli
# 66292             /Organization/Zumodrive             zumodrive
# 66298             /Organization/Zuoyebang             Zuoyebang
#
#                                             homepage_url  \
# 84                                                   NaN
# 122                                                  NaN
# 150                                                  NaN
# 171    http://www.informatica.com/us/products/messagi...
# 203                                                  NaN
# ...                                                  ...
# 66029                                                NaN
# 66081                                                NaN
# 66120                          http://www.zlotemysli.pl/
# 66292                                                NaN
# 66298                            http://zuoye.baidu.com/
#
#                                     category_list     status country_code  \
# 84                          Baby Accessories|Kids  operating          NaN
# 122                                           NaN  operating          NaN
# 150                                   Real Estate  operating          NaN
# 171                                           NaN   acquired          NaN
# 203                                      Software   acquired          NaN
# ...                                           ...        ...          ...
# 66029                              Services|Solar  operating          NaN
# 66081        Coupons|Discounts|Gift Card|QR Codes   acquired          NaN
# 66120                                         NaN  operating          NaN
# 66292  Cloud Computing|Digital Media|File Sharing  operating          NaN
# 66298                                         NaN  operating          NaN
#
#       state_code region city founded_at
# 84           NaN    NaN  NaN        NaN
# 122          NaN    NaN  NaN        NaN
# 150          NaN    NaN  NaN        NaN
# 171          NaN    NaN  NaN        NaN
# 203          NaN    NaN  NaN        NaN
# ...          ...    ...  ...        ...
# 66029        NaN    NaN  NaN        NaN
# 66081        NaN    NaN  NaN        NaN
# 66120        NaN    NaN  NaN        NaN
# 66292        NaN    NaN  NaN        NaN
# 66298        NaN    NaN  NaN        NaN
#
# [1149 rows x 10 columns]

# %%
# companies = companies.drop('founded_at', axis=1)
# companies = companies.drop('region', axis=1)
# companies = companies.drop('homepage_url', axis=1)

# %%
companies.loc[companies['status']=='closed']
# Out:
#                             permalink                 name  \
# 34         /Organization/10Bestthings         10BestThings
# 47        /Organization/11I-Solutions        11i Solutions
# 76               /Organization/169-St              169 ST.
# 85         /Organization/180Solutions         180Solutions
# 88                 /Organization/1Bib                 1bib
# ...                               ...                  ...
# 66318             /Organization/Zuvvu                Zuvvu
# 66335              /Organization/Zygo  Zygo Communications
# 66338             /Organization/Zykis                Zykis
# 66343           /Organization/Zymetis              Zymetis
# 66358  /Organization/Zyraz-Technology     Zyraz Technology
#
#                                            category_list  status country_code  \
# 34                                           Curated Web  closed          USA
# 47                                   Enterprise Software  closed          USA
# 76                                   Entertainment|Games  closed          USA
# 85         Advertising|Advertising Platforms|Promotional  closed          USA
# 88                                      Cars|Curated Web  closed          CHN
# ...                                                  ...     ...          ...
# 66318  Advertising|Social Media Advertising|Social Me...  closed          IND
# 66335                                         Mobile|SMS  closed          GBR
# 66338  Automotive|Data Security|Education|Kids|Portal...  closed          USA
# 66343                                      Biotechnology  closed          USA
# 66358                                      Biotechnology  closed          MYS
#
#       state_code                   city
# 34            OH              Cleveland
# 47            AL             Huntsville
# 76            FL              Lake Mary
# 85            WA               Bellevue
# 88            30              Guangzhou
# ...          ...                    ...
# 66318          9              Ahmadabad
# 66335         H9                 London
# 66338         CA                 Irvine
# 66343         MD           College Park
# 66358         14  Damansara New Village
#
# [6238 rows x 7 columns]

# %%
# companies[companies.isnull().sum(axis=1) > 3]
companies.loc[(companies.isnull().sum(axis=1) > 3) & (companies['status']=='closed')  & (companies['status']=='closed')]
# Out:
#                                   permalink                     name  \
# 160                  /Organization/24Med-Sp                 24med Sp
# 213     /Organization/30Secondstofly-Claire  30SecondsToFly - Claire
# 267                 /Organization/3D-Simo-2                  3D simo
# 281                  /Organization/3Divaz-2                   3DIVAZ
# 370           /Organization/4Front-Security          4Front Security
# ...                                     ...                      ...
# 65626        /Organization/Zapgocharger-Ltd         Zapgocharger Ltd
# 65745          /Organization/Zelena-Posta-2             Zelena Posta
# 66053  /Organization/Zip-Trade-Technologies   Zip Trade Technologies
# 66112                /Organization/Zkey-Com                 Zkey.com
# 66115                  /Organization/Zlango                   Zlango
#
#       category_list  status country_code state_code city
# 160             NaN  closed          NaN        NaN  NaN
# 213             NaN  closed          NaN        NaN  NaN
# 267             NaN  closed          NaN        NaN  NaN
# 281             NaN  closed          NaN        NaN  NaN
# 370             NaN  closed          NaN        NaN  NaN
# ...             ...     ...          ...        ...  ...
# 65626           NaN  closed          NaN        NaN  NaN
# 65745           NaN  closed          NaN        NaN  NaN
# 66053           NaN  closed          NaN        NaN  NaN
# 66112           NaN  closed          NaN        NaN  NaN
# 66115           NaN  closed          NaN        NaN  NaN
#
# [650 rows x 7 columns]

# %%
round(100*(companies.isnull().sum()/len(companies.index)), 2)
# Out:
# permalink         0.00
# name              0.00
# category_list     4.74
# status            0.00
# country_code     10.48
# state_code       12.88
# city             12.10
# dtype: float64

# %%
companies[companies.isnull().sum(axis=1) > 3]
# companies.loc[:, ['category_list','country_code','state_code','region','city']].describe()
# Out:
#                                  permalink                     name  \
# 79                  /Organization/17-Media                 17 Media
# 122               /Organization/2-Ladoshki               2 Ladoshki
# 160                 /Organization/24Med-Sp                 24med Sp
# 171                   /Organization/29West                   29West
# 213    /Organization/30Secondstofly-Claire  30SecondsToFly - Claire
# ...                                    ...                      ...
# 66112               /Organization/Zkey-Com                 Zkey.com
# 66115                 /Organization/Zlango                   Zlango
# 66120            /Organization/Zlote-Mysli              Zlote Mysli
# 66298              /Organization/Zuoyebang                Zuoyebang
# 66365                 /Organization/ÃEron                   ÃERON
#
#       category_list     status country_code state_code city
# 79              NaN  operating          NaN        NaN  NaN
# 122             NaN  operating          NaN        NaN  NaN
# 160             NaN     closed          NaN        NaN  NaN
# 171             NaN   acquired          NaN        NaN  NaN
# 213             NaN     closed          NaN        NaN  NaN
# ...             ...        ...          ...        ...  ...
# 66112           NaN     closed          NaN        NaN  NaN
# 66115           NaN     closed          NaN        NaN  NaN
# 66120           NaN  operating          NaN        NaN  NaN
# 66298           NaN  operating          NaN        NaN  NaN
# 66365           NaN  operating          NaN        NaN  NaN
#
# [1542 rows x 7 columns]

# %%
companies['city'].describe()
# Out:
# count             58340
# unique             5111
# top       San Francisco
# freq               3526
# Name: city, dtype: object

# %%
companies[''].describe()
# Out:
#                    permalink   name                homepage_url category_list  \
# count                  66368  66367                       61310         63220
# unique                 66368  66102                       61191         27296
# top     /Organization/Viavoo  Roost  http://www.askforoffer.com      Software
# freq                       1      4                           5          3995
#
#            status country_code state_code       region           city
# count       66368        59410      57821        58338          58340
# unique          4          137        311         1092           5111
# top     operating          USA         CA  SF Bay Area  San Francisco
# freq        53034        37601      12900         8804           3526

# %%
round(100*len(companies[companies.isnull().sum(axis=1) >4].index)/len(companies.index), 2)
# Out:
# 3.56

# %%
companies_df['name'].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-decbbbe0efe9> in <module>
# ----> 1 companies_df['name'].nunique()
#
# NameError: name 'companies_df' is not defined

# %%
companies_df.drop_duplicates()
# Out:
#                                                permalink  \
# 0                                    /Organization/-Fame
# 1                                 /Organization/-Qounter
# 2                    /Organization/-The-One-Of-Them-Inc-
# 3                                  /Organization/0-6-Com
# 4                         /Organization/004-Technologies
# ...                                                  ...
# 66363  /Organization/Zznode-Science-And-Technology-Co...
# 66364                          /Organization/Zzzzapp-Com
# 66365                               /Organization/ÃEron
# 66366                             /Organization/ÃAsys-2
# 66367  /Organization/Ä°Novatiff-Reklam-Ve-Tanä±Tä±M-H...
#
#                                                 name  \
# 0                                              #fame
# 1                                           :Qounter
# 2                             (THE) ONE of THEM,Inc.
# 3                                            0-6.com
# 4                                   004 Technologies
# ...                                              ...
# 66363                  ZZNode Science and Technology
# 66364                          Zzzzapp Wireless ltd.
# 66365                                         ÃERON
# 66366                                         Ãasys
# 66367  Ä°novatiff Reklam ve TanÄ±tÄ±m Hizmetleri Tic
#
#                             homepage_url  \
# 0                     http://livfame.com
# 1                 http://www.qounter.com
# 2                    http://oneofthem.jp
# 3                     http://www.0-6.com
# 4      http://004gmbh.de/en/004-interact
# ...                                  ...
# 66363              http://www.zznode.com
# 66364             http://www.zzzzapp.com
# 66365               http://www.aeron.hu/
# 66366               http://www.oasys.io/
# 66367               http://inovatiff.com
#
#                                            category_list     status  \
# 0                                                  Media  operating
# 1      Application Platforms|Real Time|Social Network...  operating
# 2                                      Apps|Games|Mobile  operating
# 3                                            Curated Web  operating
# 4                                               Software  operating
# ...                                                  ...        ...
# 66363                                Enterprise Software  operating
# 66364        Advertising|Mobile|Web Development|Wireless  operating
# 66365                                                NaN  operating
# 66366  Consumer Electronics|Internet of Things|Teleco...  operating
# 66367                 Consumer Goods|E-Commerce|Internet  operating
#
#       country_code state_code                 region           city  \
# 0              IND         16                 Mumbai         Mumbai
# 1              USA         DE             DE - Other  Delaware City
# 2              NaN        NaN                    NaN            NaN
# 3              CHN         22                Beijing        Beijing
# 4              USA         IL  Springfield, Illinois      Champaign
# ...            ...        ...                    ...            ...
# 66363          CHN         22                Beijing        Beijing
# 66364          HRV         15                  Split          Split
# 66365          NaN        NaN                    NaN            NaN
# 66366          USA         CA            SF Bay Area  San Francisco
# 66367          NaN        NaN                    NaN            NaN
#
#        founded_at
# 0             NaN
# 1      04-09-2014
# 2             NaN
# 3      01-01-2007
# 4      01-01-2010
# ...           ...
# 66363         NaN
# 66364  13-05-2012
# 66365  01-01-2011
# 66366  01-01-2014
# 66367         NaN
#
# [66368 rows x 10 columns]

# %%
companies_df['permalink'].nunique()
# Out:
# 66368

# %%
companies_df['permalink'].count()
# Out:
# 66368

# %%
companies_df['homepage_url'].nunique()
# Out:
# 61191

# %%
companies_df['homepage_url'].count()
# Out:
# 61310

# %%
mapping_df.shape
# Out:
# (688, 10)

# %%
ndf = mapping_df.melt(id_vars =['category_list'], value_vars =['Automotive & Sports', 'Blanks', 'Cleantech / Semiconductors'])
ndf.tail()
# Out:
#          category_list                    variable  value
# 2059         Wholesale  Cleantech / Semiconductors      0
# 2060  Wine And Spirits  Cleantech / Semiconductors      0
# 2061          Wireless  Cleantech / Semiconductors      0
# 2062             Women  Cleantech / Semiconductors      0
# 2063      Young Adults  Cleantech / Semiconductors      0
